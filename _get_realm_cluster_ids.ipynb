# %%
import mplusdb
import time
import requests
import blizzard_api
import sys
import blizzard_credentials

# %%
auth = blizzard_credentials.Credentials('.api_tokens')
access_token = auth.access_token

# %%
mdb = mplusdb.MplusDatabase('.db_config')
realms = mdb.get_utility_table('realm')

# %%
realms
# Out:
#      cluster_id  realm_id                        name  \
# 0          3694         1                Lightbringer
# 1          1168         2                    Cenarius
# 2           151         3                       Uther
# 3             4         4                     Kilrogg
# 4             5         5                  Proudmoore
# ..          ...       ...                         ...
# 551         985      1049                Wrathbringer
# 552         999      1054                      Arthas
# 553         963      1056                  Quel'dorei
# 554         964      1057                    Icecrown
# 555        3663      2075  Order of the Cloud Serpent
#
#                       name_slug  region locale             timezone
# 0                  lightbringer       1   enUS  America/Los_Angeles
# 1                      cenarius       1   enUS  America/Los_Angeles
# 2                         uther       1   enUS      America/Chicago
# 3                       kilrogg       1   enUS  America/Los_Angeles
# 4                    proudmoore       1   enUS  America/Los_Angeles
# ..                          ...     ...    ...                  ...
# 551                wrathbringer       4   zhTW          Asia/Taipei
# 552                      arthas       4   zhTW          Asia/Taipei
# 553                   queldorei       4   zhTW          Asia/Taipei
# 554                    icecrown       4   zhTW          Asia/Taipei
# 555  order-of-the-cloud-serpent       4   zhTW          Asia/Taipei
#
# [556 rows x 7 columns]

# %%
call_factory = blizzard_api.UrlFactory(
    region = 'us', 
    access_token = access_token)

realm_index_call = call_factory.get_connected_realm_index_call()
response = requests.get(realm_index_call)
realm_index_json = response.json()

parser = blizzard_api.ResponseParser()
cluster_ids = parser.parse_connected_realm_index_json(realm_index_json)

# %%
print(len(cluster_ids))
# Out:
# 84

# %%
old_cluster_ids = realms.loc[realms.region==1, 'cluster_id']
old_cluster_ids = sorted(list(set(old_cluster_ids)))

cluster_ids = [int(i) for i in cluster_ids]

print("new clusters 9/2020:")
for cluster_id in cluster_ids:
    if cluster_id not in old_cluster_ids:
        print(cluster_id)
print('-'*10)
print("clusters merged into others 9/2020:")
for old_cluster_id in old_cluster_ids:
    if old_cluster_id not in cluster_ids:
        print(old_cluster_id)
# Out:
# new clusters 9/2020:
# ----------
# clusters merged into others 9/2020:
# 7
# 10
# 51
# 70
# 74
# 85
# 87
# 90
# 91
# 98
# 101
# 105
# 116
# 119
# 123
# 128
# 153
# 156
# 159
# 1069
# 1146
# 1165
# 1169
# 1173
# 1174
# 1182
# 3677
# 3722
# 3724
# 3728
# 3729

# %%
help(blizzard_api)
# Out:
# Help on module blizzard_api:
#
# NAME
#     blizzard_api - Classes to query and parse World of Warcraft  (WoW) M+ game data.
#
# DESCRIPTION
#     Blizzard/WoW API docs:
#     https://develop.battle.net/documentation/world-of-warcraft/game-data-apis
#
# CLASSES
#     builtins.object
#         Caller
#         KeyRun
#         KeyRunLeaderboard
#         RealmRecord
#         ResponseParser
#         RosterMember
#         UrlFactory
#
#     class Caller(builtins.object)
#      |  Abstracts API interactions into a high-level interface.
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, access_token=None)
#      |      Inits wtih access token. If no token, tries to get one.
#      |
#      |  get_class_spec_table(self)
#      |      Gets class/spec table.
#      |
#      |  get_leaderboard(self, region, realm, dungeon, period)
#      |      Gets leaderboard for specified region/realm/dungeon/period.
#      |
#      |  get_spec_by_index(self, spec_index)
#      |      Returns full info for spec.
#      |
#      |  get_spec_indices(self)
#      |      Gets list of spec ids and names.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  send_request(call_url)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class KeyRun(builtins.object)
#      |  Container/parser for individual m+ run.
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, key_run_json, region)
#      |      Inits record with key run json.
#      |
#      |  generate_id(self, region)
#      |      Creates a unique record id for the run.
#      |
#      |  get_composition_vector(self)
#      |      Construct one-hot style vector to repsent spec composition.
#      |
#      |  get_members_as_tuple_list(self)
#      |      Returns roster members as list of tuples.
#      |
#      |  parse_json(self)
#      |      Parses the key run json string.
#      |
#      |  parse_roster(self, members)
#      |      Extracts player info as a list of RosterMember objects.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class KeyRunLeaderboard(builtins.object)
#      |  Container/parser for Key Run leaderboard.
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, json)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  concat_rosters_for_sql_insert(self)
#      |      Joins roster data into a single list.
#      |
#      |      Each item in the list is a character string
#      |      formatted for an SQL insert.
#      |
#      |      Warning: high-level key data is is handled separately:
#      |          see concat_runs_for_sql_insert()
#      |
#      |  concat_runs_for_sql_insert(self)
#      |      Joins leaderboard runs into a single list.
#      |
#      |      Each item in the list is a string formatted for an SQL insert.
#      |
#      |      Warning: Roster data is handled separately:
#      |          see concat_roster_for_sql_insert()
#      |
#      |  get_meta_features(self)
#      |      Extracts leaderboard regon-level data.
#      |
#      |  get_rosters_as_tuple_list(self)
#      |      Returns roster data collated as list of tuples.
#      |
#      |  get_run_comps_as_vector_list(self)
#      |      Return roster class/spec composition as list of lists.
#      |
#      |  get_runs_as_tuple_list(self)
#      |      Return leaderboard as list of tuples, where each tuple is a run.
#      |
#      |      This list is meant to be fed to an SQL connector for a batch insert.
#      |
#      |  parse_key_runs(self)
#      |      Unrolls runs/groups component into list of key run records.
#      |
#      |      Parses the 'leading_groups' component of the json, which
#      |      contains a ranking of up to 500 individual key runs.
#      |
#      |      If 'leading_groups' missing returns None.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class RealmRecord(builtins.object)
#      |  Container/parser for realm/shard info.
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, json)
#      |      Inits with realm json component of realm id call return.
#      |
#      |  generate_primary_key(self)
#      |      Generates a unique key for record.
#      |
#      |      This will serve as PRIMARY KEY in the db table.
#      |
#      |  get_data_for_database_table_as_dict(self)
#      |      Returns MDB-relevant portion of the record as dict.
#      |
#      |  get_data_for_database_table_as_tuple(self)
#      |      Returns MDB-relevant portion of the record as tuple.
#      |
#      |  parse_json(self)
#      |      Unrolls the realm json.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class ResponseParser(builtins.object)
#      |  Parse Blizzard response Json.
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, json=None)
#      |      Inits with rolled-up json string.
#      |
#      |  parse_connected_realm_index_json(self, json)
#      |      Unrolls json from a connected realm index call.
#      |
#      |  parse_connected_realm_json(self, json)
#      |      Parses connected realm call json output.
#      |
#      |  parse_timeperiod_index_json(self, json)
#      |      Retrieves time period ids from periond index call json.
#      |
#      |  parse_timeperiod_json(self, json)
#      |      Retrieves start and end timestamps from period json.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  get_realm_id_from_url(connected_realm_url)
#      |      Parsess realm ID from the json.
#      |
#      |  parse_keyrun_leaderboard_json(json)
#      |      Parses the key run leaderboard of the json.
#      |
#      |  parse_spec_index_json(json)
#      |      Parses spec index call response.
#      |
#      |  parse_spec_json(json)
#      |      Parses playable spec json.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class RosterMember(builtins.object)
#      |  Container for player character from a key run.
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, profile)
#      |      Inits with profile element of the 'members' json.
#      |
#      |  parse_profile(self, profile)
#      |      Parses character features (name, realm, etc).
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class UrlFactory(builtins.object)
#      |  API url call constructor.
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, access_token, region)
#      |      Inits with access token.
#      |
#      |      Token is generated via _XXX_ call.
#      |
#      |  get_connected_realm_call(self, realm_id)
#      |      Constructs call for a given connected realm.
#      |
#      |  get_connected_realm_index_call(self)
#      |      Constucts API call to get list of individual realm calls.
#      |
#      |  get_mythic_plus_leaderboard_url(self, dungeon_id, realm_id, period)
#      |      Constructs call to mythic+ leaderboard.
#      |
#      |  get_request_call_url(self, endpoint, namespace)
#      |      Constructs request call from endpoint and params.
#      |
#      |  get_spec_index_url(self)
#      |      Returns indices of playable specializations.
#      |
#      |  get_spec_url(self, spec_id)
#      |      Return url for playable spec call.
#      |
#      |  get_timeperiod_index_url(self)
#      |      Constructs url for timeperiod index call.
#      |
#      |  get_timeperiod_url(self, period)
#      |      Constructs url for time period call.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  get_host(region)
#      |      Constucts host name component of the request call.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
# FILE
#     /home/xyz/Documents/CodeRepos/blizzard_api/blizzard_api.py
